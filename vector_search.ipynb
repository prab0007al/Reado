# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd
books = pd.read_csv("books_cleaned.csv")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5192  9788172235222 On A Train Journey Home To North...
# 5193  9788173031014 This book tells the tale of a ma...
# 5194  9788179921623 Wisdom to Create a Life of Passi...
# 5195  9788185300535 This collection of the timeless ...
# 5196  9789027712059 Since the three volume edition o...
#
# [5197 rows x 13 columns]

# %%
books["tagged_description"]
# Out:
# 0       9780002005883 A NOVEL THAT READERS and critics...
# 1       9780002261982 A new 'Christie for Christmas' -...
# 2       9780006178736 A memorable, mesmerizing heroine...
# 3       9780006280897 Lewis' work on the nature of lov...
# 4       9780006280934 "In The Problem of Pain, C.S. Le...
#                               ...
# 5192    9788172235222 On A Train Journey Home To North...
# 5193    9788173031014 This book tells the tale of a ma...
# 5194    9788179921623 Wisdom to Create a Life of Passi...
# 5195    9788185300535 This collection of the timeless ...
# 5196    9789027712059 Since the three volume edition o...
# Name: tagged_description, Length: 5197, dtype: object

# %%
books["tagged_description"].to_csv("tagged_description.txt", index=False, sep="\n", header=False)

# %%
raw_documents = TextLoader("tagged_description.txt",encoding="utf-8", autodetect_encoding=True).load()
text_splitter = CharacterTextSplitter(chunk_size=1, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1168, which is longer than the specified 1
# Created a chunk of size 1214, which is longer than the specified 1
# Created a chunk of size 373, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 483, which is longer than the specified 1
# Created a chunk of size 482, which is longer than the specified 1
# Created a chunk of size 960, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 843, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 881, which is longer than the specified 1
# Created a chunk of size 1088, which is longer than the specified 1
# Created a chunk of size 1189, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 513, which is longer than the specified 1
# Created a chunk of size 752, which is longer than the specified 1
# Created a chunk of size 388, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 728, which is longer than the specified 1
# Created a chunk of size 721, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 473, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 1267, which is longer than the specified 1
# Created a chunk of size 681, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 553, which is longer than the specified 1
# Created a chunk of size 521, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 787, which is longer than the specified 1
# Created a chunk of size 564, which is longer than the specified 1
# Created a chunk of size 523, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 533, which is longer than the specified 1
# Created a chunk of size 559, which is longer than the specified 1
# Created a chunk of size 563, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 410, which is longer than the specified 1
# Created a chunk of size 461, which is longer than the specified 1
# Created a chunk of size 595, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 459, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 614, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 887, which is longer than the specified 1
# Created a chunk of size 693, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 277, which is longer than the specified 1
# Created a chunk of size 2010, which is longer than the specified 1
# Created a chunk of size 173, which is longer than the specified 1
# Created a chunk of size 479, which is longer than the specified 1
# Created a chunk of size 300, which is longer than the specified 1
# Created a chunk of size 520, which is longer than the specified 1
# Created a chunk of size 647, which is longer than the specified 1
# Created a chunk of size 778, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 686, which is longer than the specified 1
# Created a chunk of size 548, which is longer than the specified 1
# Created a chunk of size 1225, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 1184, which is longer than the specified 1
# Created a chunk of size 1214, which is longer than the specified 1
# Created a chunk of size 1191, which is longer than the specified 1
# Created a chunk of size 1057, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 688, which is longer than the specified 1
# Created a chunk of size 876, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 766, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 417, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 723, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 526, which is longer than the specified 1
# Created a chunk of size 521, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 899, which is longer than the specified 1
# Created a chunk of size 1270, which is longer than the specified 1
# Created a chunk of size 558, which is longer than the specified 1
# Created a chunk of size 1635, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 777, which is longer than the specified 1
# Created a chunk of size 716, which is longer than the specified 1
# Created a chunk of size 514, which is longer than the specified 1
# Created a chunk of size 958, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 1132, which is longer than the specified 1
# Created a chunk of size 168, which is longer than the specified 1
# Created a chunk of size 1325, which is longer than the specified 1
# Created a chunk of size 851, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 801, which is longer than the specified 1
# Created a chunk of size 1119, which is longer than the specified 1
# Created a chunk of size 836, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 732, which is longer than the specified 1
# Created a chunk of size 1195, which is longer than the specified 1
# Created a chunk of size 710, which is longer than the specified 1
# Created a chunk of size 773, which is longer than the specified 1
# Created a chunk of size 278, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 766, which is longer than the specified 1
# Created a chunk of size 767, which is longer than the specified 1
# Created a chunk of size 716, which is longer than the specified 1
# Created a chunk of size 2012, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 1286, which is longer than the specified 1
# Created a chunk of size 1231, which is longer than the specified 1
# Created a chunk of size 729, which is longer than the specified 1
# Created a chunk of size 750, which is longer than the specified 1
# Created a chunk of size 445, which is longer than the specified 1
# Created a chunk of size 1242, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 912, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 844, which is longer than the specified 1
# Created a chunk of size 1126, which is longer than the specified 1
# Created a chunk of size 1073, which is longer than the specified 1
# Created a chunk of size 1318, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 2834, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 570, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 367, which is longer than the specified 1
# Created a chunk of size 1141, which is longer than the specified 1
# Created a chunk of size 1004, which is longer than the specified 1
# Created a chunk of size 715, which is longer than the specified 1
# Created a chunk of size 710, which is longer than the specified 1
# Created a chunk of size 2510, which is longer than the specified 1
# Created a chunk of size 954, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 639, which is longer than the specified 1
# Created a chunk of size 405, which is longer than the specified 1
# Created a chunk of size 523, which is longer than the specified 1
# Created a chunk of size 793, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 1422, which is longer than the specified 1
# Created a chunk of size 1083, which is longer than the specified 1
# Created a chunk of size 1144, which is longer than the specified 1
# Created a chunk of size 1268, which is longer than the specified 1
# Created a chunk of size 790, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 1086, which is longer than the specified 1
# Created a chunk of size 874, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 876, which is longer than the specified 1
# Created a chunk of size 806, which is longer than the specified 1
# Created a chunk of size 1812, which is longer than the specified 1
# Created a chunk of size 1830, which is longer than the specified 1
# Created a chunk of size 1064, which is longer than the specified 1
# Created a chunk of size 955, which is longer than the specified 1
# Created a chunk of size 1180, which is longer than the specified 1
# Created a chunk of size 281, which is longer than the specified 1
# Created a chunk of size 281, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 1284, which is longer than the specified 1
# Created a chunk of size 1642, which is longer than the specified 1
# Created a chunk of size 757, which is longer than the specified 1
# Created a chunk of size 1930, which is longer than the specified 1
# Created a chunk of size 872, which is longer than the specified 1
# Created a chunk of size 2008, which is longer than the specified 1
# Created a chunk of size 2285, which is longer than the specified 1
# Created a chunk of size 173, which is longer than the specified 1
# Created a chunk of size 1003, which is longer than the specified 1
# Created a chunk of size 577, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 1142, which is longer than the specified 1
# Created a chunk of size 557, which is longer than the specified 1
# Created a chunk of size 1143, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 1086, which is longer than the specified 1
# Created a chunk of size 1483, which is longer than the specified 1
# Created a chunk of size 221, which is longer than the specified 1
# Created a chunk of size 1135, which is longer than the specified 1
# Created a chunk of size 722, which is longer than the specified 1
# Created a chunk of size 668, which is longer than the specified 1
# Created a chunk of size 765, which is longer than the specified 1
# Created a chunk of size 606, which is longer than the specified 1
# Created a chunk of size 570, which is longer than the specified 1
# Created a chunk of size 965, which is longer than the specified 1
# Created a chunk of size 857, which is longer than the specified 1
# Created a chunk of size 1032, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 367, which is longer than the specified 1
# Created a chunk of size 495, which is longer than the specified 1
# Created a chunk of size 652, which is longer than the specified 1
# Created a chunk of size 348, which is longer than the specified 1
# Created a chunk of size 733, which is longer than the specified 1
# Created a chunk of size 525, which is longer than the specified 1
# Created a chunk of size 1015, which is longer than the specified 1
# Created a chunk of size 970, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 688, which is longer than the specified 1
# Created a chunk of size 544, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 931, which is longer than the specified 1
# Created a chunk of size 564, which is longer than the specified 1
# Created a chunk of size 854, which is longer than the specified 1
# Created a chunk of size 715, which is longer than the specified 1
# Created a chunk of size 749, which is longer than the specified 1
# Created a chunk of size 712, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 1088, which is longer than the specified 1
# Created a chunk of size 723, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 704, which is longer than the specified 1
# Created a chunk of size 1912, which is longer than the specified 1
# Created a chunk of size 395, which is longer than the specified 1
# Created a chunk of size 485, which is longer than the specified 1
# Created a chunk of size 622, which is longer than the specified 1
# Created a chunk of size 559, which is longer than the specified 1
# Created a chunk of size 556, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 425, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 166, which is longer than the specified 1
# Created a chunk of size 624, which is longer than the specified 1
# Created a chunk of size 2616, which is longer than the specified 1
# Created a chunk of size 1580, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 994, which is longer than the specified 1
# Created a chunk of size 847, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 336, which is longer than the specified 1
# Created a chunk of size 1530, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 291, which is longer than the specified 1
# Created a chunk of size 2030, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 1619, which is longer than the specified 1
# Created a chunk of size 698, which is longer than the specified 1
# Created a chunk of size 822, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 843, which is longer than the specified 1
# Created a chunk of size 1189, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 508, which is longer than the specified 1
# Created a chunk of size 663, which is longer than the specified 1
# Created a chunk of size 1282, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 1268, which is longer than the specified 1
# Created a chunk of size 1277, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 1056, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 222, which is longer than the specified 1
# Created a chunk of size 784, which is longer than the specified 1
# Created a chunk of size 969, which is longer than the specified 1
# Created a chunk of size 613, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 757, which is longer than the specified 1
# Created a chunk of size 289, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 963, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 843, which is longer than the specified 1
# Created a chunk of size 786, which is longer than the specified 1
# Created a chunk of size 648, which is longer than the specified 1
# Created a chunk of size 984, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 1163, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 1058, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 875, which is longer than the specified 1
# Created a chunk of size 817, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 755, which is longer than the specified 1
# Created a chunk of size 569, which is longer than the specified 1
# Created a chunk of size 628, which is longer than the specified 1
# Created a chunk of size 868, which is longer than the specified 1
# Created a chunk of size 620, which is longer than the specified 1
# Created a chunk of size 621, which is longer than the specified 1
# Created a chunk of size 1084, which is longer than the specified 1
# Created a chunk of size 2762, which is longer than the specified 1
# Created a chunk of size 1033, which is longer than the specified 1
# Created a chunk of size 758, which is longer than the specified 1
# Created a chunk of size 773, which is longer than the specified 1
# Created a chunk of size 634, which is longer than the specified 1
# Created a chunk of size 1010, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 1064, which is longer than the specified 1
# Created a chunk of size 492, which is longer than the specified 1
# Created a chunk of size 795, which is longer than the specified 1
# Created a chunk of size 699, which is longer than the specified 1
# Created a chunk of size 485, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 1224, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 345, which is longer than the specified 1
# Created a chunk of size 657, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 767, which is longer than the specified 1
# Created a chunk of size 553, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 590, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 726, which is longer than the specified 1
# Created a chunk of size 1805, which is longer than the specified 1
# Created a chunk of size 1017, which is longer than the specified 1
# Created a chunk of size 684, which is longer than the specified 1
# Created a chunk of size 739, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 449, which is longer than the specified 1
# Created a chunk of size 472, which is longer than the specified 1
# Created a chunk of size 922, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 162, which is longer than the specified 1
# Created a chunk of size 967, which is longer than the specified 1
# Created a chunk of size 477, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 645, which is longer than the specified 1
# Created a chunk of size 676, which is longer than the specified 1
# Created a chunk of size 712, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 854, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 854, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 760, which is longer than the specified 1
# Created a chunk of size 796, which is longer than the specified 1
# Created a chunk of size 679, which is longer than the specified 1
# Created a chunk of size 927, which is longer than the specified 1
# Created a chunk of size 1268, which is longer than the specified 1
# Created a chunk of size 733, which is longer than the specified 1
# Created a chunk of size 868, which is longer than the specified 1
# Created a chunk of size 931, which is longer than the specified 1
# Created a chunk of size 772, which is longer than the specified 1
# Created a chunk of size 770, which is longer than the specified 1
# Created a chunk of size 335, which is longer than the specified 1
# Created a chunk of size 649, which is longer than the specified 1
# Created a chunk of size 1771, which is longer than the specified 1
# Created a chunk of size 534, which is longer than the specified 1
# Created a chunk of size 824, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 599, which is longer than the specified 1
# Created a chunk of size 486, which is longer than the specified 1
# Created a chunk of size 969, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 491, which is longer than the specified 1
# Created a chunk of size 844, which is longer than the specified 1
# Created a chunk of size 876, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 707, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 654, which is longer than the specified 1
# Created a chunk of size 1270, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 736, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 1019, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 777, which is longer than the specified 1
# Created a chunk of size 682, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 598, which is longer than the specified 1
# Created a chunk of size 663, which is longer than the specified 1
# Created a chunk of size 595, which is longer than the specified 1
# Created a chunk of size 857, which is longer than the specified 1
# Created a chunk of size 595, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 537, which is longer than the specified 1
# Created a chunk of size 567, which is longer than the specified 1
# Created a chunk of size 278, which is longer than the specified 1
# Created a chunk of size 705, which is longer than the specified 1
# Created a chunk of size 848, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 542, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 1177, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 458, which is longer than the specified 1
# Created a chunk of size 904, which is longer than the specified 1
# Created a chunk of size 852, which is longer than the specified 1
# Created a chunk of size 507, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 1715, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 398, which is longer than the specified 1
# Created a chunk of size 845, which is longer than the specified 1
# Created a chunk of size 1681, which is longer than the specified 1
# Created a chunk of size 721, which is longer than the specified 1
# Created a chunk of size 659, which is longer than the specified 1
# Created a chunk of size 603, which is longer than the specified 1
# Created a chunk of size 991, which is longer than the specified 1
# Created a chunk of size 1128, which is longer than the specified 1
# Created a chunk of size 462, which is longer than the specified 1
# Created a chunk of size 2005, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 1171, which is longer than the specified 1
# Created a chunk of size 2141, which is longer than the specified 1
# Created a chunk of size 662, which is longer than the specified 1
# Created a chunk of size 1322, which is longer than the specified 1
# Created a chunk of size 526, which is longer than the specified 1
# Created a chunk of size 336, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 1112, which is longer than the specified 1
# Created a chunk of size 664, which is longer than the specified 1
# Created a chunk of size 908, which is longer than the specified 1
# Created a chunk of size 1316, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 691, which is longer than the specified 1
# Created a chunk of size 950, which is longer than the specified 1
# Created a chunk of size 1121, which is longer than the specified 1
# Created a chunk of size 776, which is longer than the specified 1
# Created a chunk of size 615, which is longer than the specified 1
# Created a chunk of size 423, which is longer than the specified 1
# Created a chunk of size 533, which is longer than the specified 1
# Created a chunk of size 1018, which is longer than the specified 1
# Created a chunk of size 725, which is longer than the specified 1
# Created a chunk of size 612, which is longer than the specified 1
# Created a chunk of size 629, which is longer than the specified 1
# Created a chunk of size 463, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 1007, which is longer than the specified 1
# Created a chunk of size 616, which is longer than the specified 1
# Created a chunk of size 884, which is longer than the specified 1
# Created a chunk of size 579, which is longer than the specified 1
# Created a chunk of size 911, which is longer than the specified 1
# Created a chunk of size 1057, which is longer than the specified 1
# Created a chunk of size 630, which is longer than the specified 1
# Created a chunk of size 1255, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 572, which is longer than the specified 1
# Created a chunk of size 1098, which is longer than the specified 1
# Created a chunk of size 907, which is longer than the specified 1
# Created a chunk of size 621, which is longer than the specified 1
# Created a chunk of size 381, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 448, which is longer than the specified 1
# Created a chunk of size 877, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 1143, which is longer than the specified 1
# Created a chunk of size 877, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 620, which is longer than the specified 1
# Created a chunk of size 625, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 551, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 841, which is longer than the specified 1
# Created a chunk of size 481, which is longer than the specified 1
# Created a chunk of size 714, which is longer than the specified 1
# Created a chunk of size 921, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 581, which is longer than the specified 1
# Created a chunk of size 744, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 800, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 541, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 750, which is longer than the specified 1
# Created a chunk of size 612, which is longer than the specified 1
# Created a chunk of size 495, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 611, which is longer than the specified 1
# Created a chunk of size 587, which is longer than the specified 1
# Created a chunk of size 311, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 809, which is longer than the specified 1
# Created a chunk of size 599, which is longer than the specified 1
# Created a chunk of size 276, which is longer than the specified 1
# Created a chunk of size 1550, which is longer than the specified 1
# Created a chunk of size 590, which is longer than the specified 1
# Created a chunk of size 827, which is longer than the specified 1
# Created a chunk of size 664, which is longer than the specified 1
# Created a chunk of size 877, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 736, which is longer than the specified 1
# Created a chunk of size 429, which is longer than the specified 1
# Created a chunk of size 723, which is longer than the specified 1
# Created a chunk of size 507, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 422, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 923, which is longer than the specified 1
# Created a chunk of size 330, which is longer than the specified 1
# Created a chunk of size 547, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 1652, which is longer than the specified 1
# Created a chunk of size 873, which is longer than the specified 1
# Created a chunk of size 1495, which is longer than the specified 1
# Created a chunk of size 362, which is longer than the specified 1
# Created a chunk of size 474, which is longer than the specified 1
# Created a chunk of size 736, which is longer than the specified 1
# Created a chunk of size 527, which is longer than the specified 1
# Created a chunk of size 612, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 538, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 545, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 461, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 293, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 473, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 723, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 976, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 175, which is longer than the specified 1
# Created a chunk of size 926, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 674, which is longer than the specified 1
# Created a chunk of size 789, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 636, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 416, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 615, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 991, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 265, which is longer than the specified 1
# Created a chunk of size 448, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 341, which is longer than the specified 1
# Created a chunk of size 676, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 293, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 450, which is longer than the specified 1
# Created a chunk of size 581, which is longer than the specified 1
# Created a chunk of size 583, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 775, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 530, which is longer than the specified 1
# Created a chunk of size 178, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 178, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 613, which is longer than the specified 1
# Created a chunk of size 832, which is longer than the specified 1
# Created a chunk of size 276, which is longer than the specified 1
# Created a chunk of size 318, which is longer than the specified 1
# Created a chunk of size 434, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 824, which is longer than the specified 1
# Created a chunk of size 314, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 886, which is longer than the specified 1
# Created a chunk of size 1277, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 666, which is longer than the specified 1
# Created a chunk of size 847, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 1046, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 178, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 914, which is longer than the specified 1
# Created a chunk of size 755, which is longer than the specified 1
# Created a chunk of size 757, which is longer than the specified 1
# Created a chunk of size 945, which is longer than the specified 1
# Created a chunk of size 905, which is longer than the specified 1
# Created a chunk of size 847, which is longer than the specified 1
# Created a chunk of size 865, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 802, which is longer than the specified 1
# Created a chunk of size 837, which is longer than the specified 1
# Created a chunk of size 754, which is longer than the specified 1
# Created a chunk of size 864, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 678, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 513, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 360, which is longer than the specified 1
# Created a chunk of size 542, which is longer than the specified 1
# Created a chunk of size 816, which is longer than the specified 1
# Created a chunk of size 743, which is longer than the specified 1
# Created a chunk of size 672, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 990, which is longer than the specified 1
# Created a chunk of size 767, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 994, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 572, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 474, which is longer than the specified 1
# Created a chunk of size 639, which is longer than the specified 1
# Created a chunk of size 607, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 1666, which is longer than the specified 1
# Created a chunk of size 374, which is longer than the specified 1
# Created a chunk of size 1616, which is longer than the specified 1
# Created a chunk of size 778, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 153, which is longer than the specified 1
# Created a chunk of size 574, which is longer than the specified 1
# Created a chunk of size 669, which is longer than the specified 1
# Created a chunk of size 816, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 520, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 487, which is longer than the specified 1
# Created a chunk of size 359, which is longer than the specified 1
# Created a chunk of size 607, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# ...
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 369, which is longer than the specified 1
# Created a chunk of size 186, which is longer than the specified 1
# Created a chunk of size 314, which is longer than the specified 1
# Created a chunk of size 797, which is longer than the specified 1
# Created a chunk of size 1134, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 508, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 1348, which is longer than the specified 1
# Created a chunk of size 680, which is longer than the specified 1
# Created a chunk of size 579, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 954, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 683, which is longer than the specified 1
# Created a chunk of size 727, which is longer than the specified 1
# Created a chunk of size 656, which is longer than the specified 1
# Created a chunk of size 1084, which is longer than the specified 1
# Created a chunk of size 794, which is longer than the specified 1
# Created a chunk of size 798, which is longer than the specified 1
# Created a chunk of size 998, which is longer than the specified 1
# Created a chunk of size 960, which is longer than the specified 1
# Created a chunk of size 659, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 756, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 509, which is longer than the specified 1
# Created a chunk of size 560, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 502, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 341, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 670, which is longer than the specified 1
# Created a chunk of size 675, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 265, which is longer than the specified 1
# Created a chunk of size 856, which is longer than the specified 1
# Created a chunk of size 1108, which is longer than the specified 1
# Created a chunk of size 540, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 451, which is longer than the specified 1
# Created a chunk of size 981, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 1340, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 289, which is longer than the specified 1
# Created a chunk of size 761, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 1298, which is longer than the specified 1
# Created a chunk of size 720, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 370, which is longer than the specified 1
# Created a chunk of size 1320, which is longer than the specified 1
# Created a chunk of size 1524, which is longer than the specified 1
# Created a chunk of size 1031, which is longer than the specified 1
# Created a chunk of size 705, which is longer than the specified 1
# Created a chunk of size 1255, which is longer than the specified 1
# Created a chunk of size 710, which is longer than the specified 1
# Created a chunk of size 1125, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 1293, which is longer than the specified 1
# Created a chunk of size 397, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 1041, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 500, which is longer than the specified 1
# Created a chunk of size 1150, which is longer than the specified 1
# Created a chunk of size 933, which is longer than the specified 1
# Created a chunk of size 661, which is longer than the specified 1
# Created a chunk of size 880, which is longer than the specified 1
# Created a chunk of size 888, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 570, which is longer than the specified 1
# Created a chunk of size 893, which is longer than the specified 1
# Created a chunk of size 528, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 909, which is longer than the specified 1
# Created a chunk of size 963, which is longer than the specified 1
# Created a chunk of size 868, which is longer than the specified 1
# Created a chunk of size 529, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 631, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 483, which is longer than the specified 1
# Created a chunk of size 510, which is longer than the specified 1
# Created a chunk of size 473, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 649, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 461, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 905, which is longer than the specified 1
# Created a chunk of size 294, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 604, which is longer than the specified 1
# Created a chunk of size 565, which is longer than the specified 1
# Created a chunk of size 667, which is longer than the specified 1
# Created a chunk of size 525, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 1155, which is longer than the specified 1
# Created a chunk of size 1350, which is longer than the specified 1
# Created a chunk of size 1403, which is longer than the specified 1
# Created a chunk of size 975, which is longer than the specified 1
# Created a chunk of size 411, which is longer than the specified 1
# Created a chunk of size 413, which is longer than the specified 1
# Created a chunk of size 282, which is longer than the specified 1
# Created a chunk of size 291, which is longer than the specified 1
# Created a chunk of size 580, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 637, which is longer than the specified 1
# Created a chunk of size 1898, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 2149, which is longer than the specified 1
# Created a chunk of size 344, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 1417, which is longer than the specified 1
# Created a chunk of size 586, which is longer than the specified 1
# Created a chunk of size 973, which is longer than the specified 1
# Created a chunk of size 1419, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 170, which is longer than the specified 1
# Created a chunk of size 840, which is longer than the specified 1
# Created a chunk of size 1387, which is longer than the specified 1
# Created a chunk of size 486, which is longer than the specified 1
# Created a chunk of size 507, which is longer than the specified 1
# Created a chunk of size 1280, which is longer than the specified 1
# Created a chunk of size 1287, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 677, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 1043, which is longer than the specified 1
# Created a chunk of size 416, which is longer than the specified 1
# Created a chunk of size 2742, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 866, which is longer than the specified 1
# Created a chunk of size 603, which is longer than the specified 1
# Created a chunk of size 404, which is longer than the specified 1
# Created a chunk of size 1182, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 654, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 1000, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 295, which is longer than the specified 1
# Created a chunk of size 312, which is longer than the specified 1
# Created a chunk of size 796, which is longer than the specified 1
# Created a chunk of size 3938, which is longer than the specified 1
# Created a chunk of size 923, which is longer than the specified 1
# Created a chunk of size 695, which is longer than the specified 1
# Created a chunk of size 853, which is longer than the specified 1
# Created a chunk of size 928, which is longer than the specified 1
# Created a chunk of size 548, which is longer than the specified 1
# Created a chunk of size 1019, which is longer than the specified 1
# Created a chunk of size 395, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 398, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 1108, which is longer than the specified 1
# Created a chunk of size 330, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 365, which is longer than the specified 1
# Created a chunk of size 440, which is longer than the specified 1
# Created a chunk of size 1273, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 1964, which is longer than the specified 1
# Created a chunk of size 540, which is longer than the specified 1
# Created a chunk of size 1529, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 375, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 612, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 1302, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 328, which is longer than the specified 1
# Created a chunk of size 519, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 999, which is longer than the specified 1
# Created a chunk of size 767, which is longer than the specified 1
# Created a chunk of size 291, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 561, which is longer than the specified 1
# Created a chunk of size 651, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 1048, which is longer than the specified 1
# Created a chunk of size 1272, which is longer than the specified 1
# Created a chunk of size 950, which is longer than the specified 1
# Created a chunk of size 451, which is longer than the specified 1
# Created a chunk of size 384, which is longer than the specified 1
# Created a chunk of size 682, which is longer than the specified 1
# Created a chunk of size 348, which is longer than the specified 1
# Created a chunk of size 584, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 1655, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 763, which is longer than the specified 1
# Created a chunk of size 1032, which is longer than the specified 1

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.')

# %%
db_books = Chroma.from_documents(documents, embedding=OpenAIEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 from langchain_community.embeddings import HuggingFaceEmbeddings
# ----> 2 db_books = Chroma.from_documents(documents, embedding=OpenAIEmbeddings())
#
# File ~\NLP\Reado\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:1371, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1369 if ids is None:
#    1370     ids = [doc.id if doc.id else str(uuid.uuid4()) for doc in documents]
# -> 1371 return cls.from_texts(
#    1372     texts=texts,
#    1373     embedding=embedding,
#    1374     metadatas=metadatas,
#    1375     ids=ids,
#    1376     collection_name=collection_name,
#    1377     persist_directory=persist_directory,
#    1378     host=host,
#    1379     port=port,
#    1380     ssl=ssl,
#    1381     headers=headers,
#    1382     chroma_cloud_api_key=chroma_cloud_api_key,
#    1383     tenant=tenant,
#    1384     database=database,
#    1385     client_settings=client_settings,
#    1386     client=client,
#    1387     collection_metadata=collection_metadata,
#    1388     collection_configuration=collection_configuration,
#    1389     **kwargs,
#    1390 )
#
# File ~\NLP\Reado\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:1304, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1296     from chromadb.utils.batch_utils import create_batches
#    1298     for batch in create_batches(
#    1299         api=chroma_collection._client,
#    1300         ids=ids,
#    1301         metadatas=metadatas,  # type: ignore[arg-type]
#    1302         documents=texts,
#    1303     ):
# -> 1304         chroma_collection.add_texts(
#    1305             texts=batch[3] if batch[3] else [],
#    1306             metadatas=batch[2] if batch[2] else None,  # type: ignore[arg-type]
#    1307             ids=batch[0],
#    1308         )
#    1309 else:
#    1310     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File ~\NLP\Reado\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:606, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     604 texts = list(texts)
#     605 if self._embedding_function is not None:
# --> 606     embeddings = self._embedding_function.embed_documents(texts)
#     607 if metadatas:
#     608     # fill metadatas with empty dicts if somebody
#     609     # did not specify metadata for all texts
#     610     length_diff = len(texts) - len(metadatas)
#
# File ~\NLP\Reado\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:591, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     588 # NOTE: to keep things simple, we assume the list may contain texts longer
#     589 #       than the maximum context and use length-safe embedding function.
#     590 engine = cast(str, self.deployment)
# --> 591 return self._get_len_safe_embeddings(
#     592     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     593 )
#
# File ~\NLP\Reado\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:479, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     477 batched_embeddings: list[list[float]] = []
#     478 for i in _iter:
# --> 479     response = self.client.create(
#     480         input=tokens[i : i + _chunk_size], **client_kwargs
#     481     )
#     482     if not isinstance(response, dict):
#     483         response = response.model_dump()
#
# File ~\NLP\Reado\.venv\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~\NLP\Reado\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\NLP\Reado\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
#!pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.55.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: tqdm in c:\users\user\nlp\reado\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.8.0-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.7.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting scipy (from sentence-transformers)
#   Downloading scipy-1.16.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\user\nlp\reado\.venv\lib\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\user\nlp\reado\.venv\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\user\nlp\reado\.venv\lib\site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in c:\users\user\nlp\reado\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\nlp\reado\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\nlp\reado\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\nlp\reado\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\user\nlp\reado\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\nlp\reado\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Collecting networkx (from torch>=1.11.0->sentence-transformers)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\user\nlp\reado\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\user\nlp\reado\.venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\nlp\reado\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\nlp\reado\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.34)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\nlp\reado\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\nlp\reado\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\nlp\reado\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\nlp\reado\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\nlp\reado\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\nlp\reado\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\nlp\reado\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# Downloading sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
#    ---------------------------------------- 0.0/483.4 kB ? eta -:--:--
#    ---------------- ----------------------- 204.8/483.4 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  481.3/483.4 kB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 483.4/483.4 kB 5.0 MB/s eta 0:00:00
# Downloading torch-2.8.0-cp311-cp311-win_amd64.whl (241.4 MB)
#    ---------------------------------------- 0.0/241.4 MB ? eta -:--:--
#    ---------------------------------------- 0.2/241.4 MB 7.0 MB/s eta 0:00:35
#    ---------------------------------------- 0.5/241.4 MB 6.6 MB/s eta 0:00:37
#    ---------------------------------------- 0.9/241.4 MB 7.0 MB/s eta 0:00:35
#    ---------------------------------------- 1.3/241.4 MB 7.3 MB/s eta 0:00:34
#    ---------------------------------------- 1.5/241.4 MB 7.0 MB/s eta 0:00:35
#    ---------------------------------------- 1.9/241.4 MB 7.5 MB/s eta 0:00:33
#    ---------------------------------------- 2.1/241.4 MB 6.8 MB/s eta 0:00:36
#    ---------------------------------------- 2.3/241.4 MB 6.3 MB/s eta 0:00:38
#    ---------------------------------------- 2.6/241.4 MB 6.4 MB/s eta 0:00:38
#    ---------------------------------------- 2.8/241.4 MB 6.2 MB/s eta 0:00:39
#    ------------ --------------------------- 75.7/241.4 MB 4.4 MB/s eta 0:00:38
#    ------------ --------------------------- 75.8/241.4 MB 4.4 MB/s eta 0:00:38
#    ------------ --------------------------- 76.0/241.4 MB 4.4 MB/s eta 0:00:38
#    ------------ --------------------------- 76.1/241.4 MB 4.4 MB/s eta 0:00:38
#    ------------ --------------------------- 76.2/241.4 MB 4.3 MB/s eta 0:00:39
#    ------------ --------------------------- 76.4/241.4 MB 4.3 MB/s eta 0:00:39
#    ------------ --------------------------- 76.5/241.4 MB 4.3 MB/s eta 0:00:39
#    ------------ --------------------------- 76.7/241.4 MB 4.3 MB/s eta 0:00:39
#    ------------ --------------------------- 76.8/241.4 MB 4.2 MB/s eta 0:00:39
#    ------------ --------------------------- 76.9/241.4 MB 4.2 MB/s eta 0:00:40
#    ------------ --------------------------- 77.1/241.4 MB 4.2 MB/s eta 0:00:40
#    ------------ --------------------------- 77.2/241.4 MB 4.1 MB/s eta 0:00:40
#    ------------ --------------------------- 77.3/241.4 MB 4.1 MB/s eta 0:00:40
#    ------------ --------------------------- 77.5/241.4 MB 4.1 MB/s eta 0:00:41
#    ------------ --------------------------- 77.6/241.4 MB 4.1 MB/s eta 0:00:41
#    ------------ --------------------------- 77.8/241.4 MB 4.0 MB/s eta 0:00:41
#    ------------ --------------------------- 77.9/241.4 MB 4.0 MB/s eta 0:00:41
#    ------------ --------------------------- 78.0/241.4 MB 4.0 MB/s eta 0:00:41
#    ------------ --------------------------- 78.2/241.4 MB 3.9 MB/s eta 0:00:42
#    ------------ --------------------------- 78.3/241.4 MB 3.9 MB/s eta 0:00:42
#    ------------- -------------------------- 78.5/241.4 MB 3.9 MB/s eta 0:00:42
#    ------------- -------------------------- 78.6/241.4 MB 3.9 MB/s eta 0:00:42
#    ------------- -------------------------- 78.8/241.4 MB 3.9 MB/s eta 0:00:43
#    ------------- -------------------------- 78.9/241.4 MB 3.9 MB/s eta 0:00:43
#    ------------- -------------------------- 79.1/241.4 MB 3.8 MB/s eta 0:00:43
#    ------------- -------------------------- 79.2/241.4 MB 3.8 MB/s eta 0:00:43
#    ------------- -------------------------- 79.4/241.4 MB 3.8 MB/s eta 0:00:43
#    ------------- -------------------------- 79.6/241.4 MB 3.8 MB/s eta 0:00:43
#    ------------- -------------------------- 79.7/241.4 MB 3.8 MB/s eta 0:00:43
#    ------------- -------------------------- 79.9/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.0/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.2/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.3/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.5/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.6/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 80.8/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 81.0/241.4 MB 3.7 MB/s eta 0:00:44
#    ------------- -------------------------- 81.1/241.4 MB 3.6 MB/s eta 0:00:45
MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.4/38.6 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.6/38.6 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.7/38.6 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.9/38.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 29.1/38.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 29.2/38.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 29.4/38.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 29.5/38.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 29.6/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------ --------- 29.8/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.1/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.3/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.4/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.6/38.6 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 30.8/38.6 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 31.0/38.6 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 31.1/38.6 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 31.3/38.6 MB 3.7 MB/s eta 0:00:02
#    -------------------------------- ------- 31.5/38.6 MB 3.7 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/38.6 MB 3.8 MB/s eta 0:00:02
#    -------------------------------- ------- 31.8/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.0/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.2/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.4/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.6/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/38.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/38.6 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.0/38.6 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.0/38.6 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.2/38.6 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.4/38.6 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.5/38.6 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.7/38.6 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.8/38.6 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.9/38.6 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.1/38.6 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.2/38.6 MB 3.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.4/38.6 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.5/38.6 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.7/38.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------------------ --- 34.8/38.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------------------ --- 35.0/38.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.2/38.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.0/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.3/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.5/38.6 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.6 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 36.8/38.6 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 36.9/38.6 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/38.6 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.6 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.3/38.6 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/38.6 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/38.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.4/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 3.2 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/307.7 kB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 256.0/307.7 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 307.7/307.7 kB 3.2 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
#    ---------------------------------------- 0.0/320.2 kB ? eta -:--:--
#    --------------- ------------------------ 122.9/320.2 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 276.5/320.2 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 320.2/320.2 kB 2.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.0 MB 3.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.0 MB 3.5 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/2.0 MB 3.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.0 MB 3.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.9/2.0 MB 3.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, scipy, safetensors, networkx, joblib, torch, scikit-learn, transformers, sentence-transformers
# Successfully installed joblib-1.5.1 networkx-3.5 safetensors-0.6.2 scikit-learn-1.7.1 scipy-1.16.1 sentence-transformers-5.1.0 threadpoolctl-3.6.0 torch-2.8.0 transformers-4.55.0
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedding_function = HuggingFaceEmbeddings(model_name=model_name)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:  92%|#########2| 83.9M/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
db_books = Chroma.from_documents(documents, embedding=embedding_function)

# %%
query = "a book to teach children about nature"
similar_docs = db_books.similarity_search(query, k= 10)
print(similar_docs)
# Out:
# [Document(id='35ccc5d6-29d0-4b01-9948-4564fc6da97a', metadata={'source': 'tagged_description.txt'}, page_content='9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.'), Document(id='dc3a93fb-f536-4384-9b43-d98ff7450073', metadata={'source': 'tagged_description.txt'}, page_content="9780786808380 Introduce your babies to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing the baby to some basic -- and sometimes playful -- information about the subjects."), Document(id='226ed752-0f3d-4469-a988-a99836c48f36', metadata={'source': 'tagged_description.txt'}, page_content="9780786808397 Introduce your baby to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to exopse little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information about the subjects."), Document(id='6984515a-5fc3-44ce-82d1-423e2cb779d7', metadata={'source': 'tagged_description.txt'}, page_content="9780060959036 Barbara Kingsolver's fifth novel is a hymn to wildness that celebrates the prodigal spirit of human nature, and of nature itself. It weaves together three stories of human love within a larger tapestry of lives amid the mountains and farms of southern Appalachia. Over the course of one humid summer, this novel's intriguing protagonists face disparate predicaments but find connections to one another and to the flora and fauna with which they necessarily share a place."), Document(id='3bc1cbe5-c2b3-4de1-bb0f-afe963ef4747', metadata={'source': 'tagged_description.txt'}, page_content="9780786808373 Introducing your baby to birds, cats, dogs, and babies through fine art, illsutration and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information on the subjects."), Document(id='293d7b2b-fa68-4905-818a-de5d6b754271', metadata={'source': 'tagged_description.txt'}, page_content="9780374522599 The Control of Nature is John McPhee's bestselling account of places where people are locked in combat with nature. Taking us deep into these contested territories, McPhee details the strageties and tactics through which people attempt to control nature. Most striking is his depiction of the main contestants: nature in complex and awesome guises, and those attempting to wrest control from her - stubborn, sometimes foolhardy, more often ingenious, and always arresting characters."), Document(id='206582dd-7386-43bb-9867-35b68bad5125', metadata={'source': 'tagged_description.txt'}, page_content='9780786819119 Charming illustrations and playful rhythmic verse make real-life learning fun by taking babies and toddlers on an adventurous discovery of water and its many sources. Squeezable and floatable, Water, Water, Everywhere can be enjoyed in and out of the tub.'), Document(id='c866694c-ce5d-472b-95fd-d546018b6d96', metadata={'source': 'tagged_description.txt'}, page_content="9780064402453 ‘Racso, a brash and boastful little rodent, is making his way to Thorn Valley, determined to learn how to read and write and become a hero. His bragging and lies get him off to a bad start, but a crisis gives him the opportunity to prove his mettle. A worthy successor [to Mrs. Frisby and the Rats of ...

# %%
books[books["isbn13"]==int(similar_docs[0].page_content.split()[0].strip())]
# Out:
#              isbn13      isbn10                                title  \
# 3747  9780786808069  0786808063  Baby Einstein: Neighborhood Animals
#
#                                 authors        categories  \
# 3747  Marilyn Singer;Julie Aigner-Clark  Juvenile Fiction
#
#                                               thumbnail  \
# 3747  http://books.google.com/books/content?id=X9a4P...
#
#                                             description  published_year  \
# 3747  Children will discover the exciting world of t...          2001.0
#
#       average_rating  num_pages  ratings_count  \
# 3747            3.89       16.0          180.0
#
#                        title_and_subtitle  \
# 3747  Baby Einstein: Neighborhood Animals
#
#                                      tagged_description
# 3747  9780786808069 Children will discover the excit...

# %%
def retrieve_semantic_recommendations(
        query : str,
        top_k : int = 50,
)->pd.DataFrame:
    recs = db_books.similarity_search(query, k= 50)

    books_list = []

    for i in range(0, len(recs)):
        books_list += [int(recs[i].page_content.strip('"').split()[0])]

    return books[books['isbn13'].isin(books_list)].head(top_k)

# %%
retrieve_semantic_recommendations("A man does suicide")
# Out:
#              isbn13      isbn10                                   title  \
# 112   9780060506049  0060506040                    Worlds Enough & Time
# 158   9780060577049  0060577045                Slouching Toward Nirvana
# 253   9780060840884  0060840889                              Hit Parade
# 387   9780061177590  0061177598                                   Women
# 451   9780072920963  0072920963                          The Last Dance
# 521   9780099481249  0099481243                           Enduring Love
# 582   9780140178135  0140178139                               Leviathan
# 828   9780142437636  0142437638                             Agapē Agape
# 854   9780143037231  0143037234                       The Big Over Easy
# 1145  9780307275561  0307275566                             Death Match
# 1157  9780310217602  0310217601                           Trial by Fire
# 1204  9780312277109  0312277105                    An Unfortunate Woman
# 1322  9780312982867  0312982860                          True Believers
# 1358  9780316578998  0316578991                          The Black Veil
# 1485  9780345437839  0345437837           The Case of the Curious Bride
# 1503  9780345446664  0345446666                    Death in Holy Orders
# 1516  9780345457691  0345457692                          Altered Carbon
# 1580  9780349100470  0349100470               The Drowned and the Saved
# 1669  9780375507151  0375507159                       Cliffs of Despair
# 1675  9780375701474  0375701478                        Night Falls Fast
# 1769  9780380732029  0380732025                            Killing Time
# 1916  9780393321982  0393321983                    Strangers on a Train
# 1988  9780413772329  0413772322           Resuscitation of a Hanged Man
# 2028  9780425182871  0425182878                             Chosen Prey
# 2050  9780425198001  0425198006                            Odds Against
# 2088  9780425214435  0425214435                            Eyes of Prey
# 2094  9780435233075  0435233076                     Death of a Salesman
# 2185  9780440234746  0440234743                           The Testament
# 2253  9780445405561  0445405562                    Cast a Yellow Shadow
# 2266  9780446578424  0446578428                 The Serial Killers Club
# 2281  9780446608282  0446608289                      Death of an Addict
